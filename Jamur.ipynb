# %%
# import the necessary packages
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from PIL import Image
from imutils import paths
import numpy as np
import argparse
import os
import mahotas
import cv2
import h5py
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
bins             = 8
fixed_size       = tuple((200,200))

# %%
def fd_hu_moments(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    feature = cv2.HuMoments(cv2.moments(image)).flatten()
    return feature

# %%
def fd_haralick(image):
    # convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # compute the haralick texture feature vector
    haralick = mahotas.features.haralick(gray).mean(axis=0)
    # return the result
    return haralick

# %%
def fd_histogram(image, mask=None):
    # convert the image to HSV color-space
    image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    # compute the color histogram
    hist  = cv2.calcHist([image], [0, 1, 2], None, [bins, bins, bins], [0, 256, 0, 256, 0, 256])
    # normalize the histogram
    cv2.normalize(hist, hist)
    # return the histogram
    return hist.flatten()

# %%
# define the dictionary of models our script can use, where the key
# to the dictionary is the name of the model (supplied via command
# line argument) and the value is the model itself
models = {
    "knn": KNeighborsClassifier(n_neighbors=5),
    "naive_bayes": GaussianNB(),
    "logit": LogisticRegression(solver="lbfgs", multi_class="auto"),
    "svm": SVC(kernel="linear"),
    "decision_tree": DecisionTreeClassifier(),
    "random_forest": RandomForestClassifier(n_estimators=100),
    "mlp": MLPClassifier()
}

# %%
# grab all image paths in the input dataset directory, initialize our
# list of extracted features and corresponding labels
print("[INFO] extracting image features...")
imagePaths = paths.list_images("Jamur")
data = []
labels = []
i = 1
 
# loop over our input images
for imagePath in imagePaths:
    # load the input image from disk, compute color channel
    # statistics, and then update our data list
    image = np.array(cv2.imread(imagePath), dtype=np.uint8)
    image = cv2.resize(image, fixed_size)
    fv_hu_moments = fd_hu_moments(image)
    fv_haralick   = fd_haralick(image)
    fv_histogram  = fd_histogram(image)
    features = np.hstack([fv_histogram, fv_haralick, fv_hu_moments])
    data.append(features)
    
    # extract the class label from the file path and update the
    # labels list
    label = imagePath.split(os.path.sep)[-2]
    labels.append(label)
    print("Image {} done".format(i))
    i = i+1

print("[INFO] Process done")
# Out:
# [INFO] extracting image features...
# Image 1 done
# Image 2 done
# Image 3 done
# Image 4 done
# Image 5 done
# Image 6 done
# Image 7 done
# Image 8 done
# Image 9 done
# Image 10 done
# Image 11 done
# Image 12 done
# Image 13 done
# Image 14 done
# Image 15 done
# Image 16 done
# Image 17 done
# Image 18 done
# Image 19 done
# Image 20 done
# Image 21 done
# Image 22 done
# Image 23 done
# Image 24 done
# Image 25 done
# Image 26 done
# Image 27 done
# Image 28 done
# Image 29 done
# Image 30 done
# Image 31 done
# Image 32 done
# Image 33 done
# Image 34 done
# Image 35 done
# Image 36 done
# Image 37 done
# Image 38 done
# Image 39 done
# Image 40 done
# Image 41 done
# Image 42 done
# Image 43 done
# Image 44 done
# Image 45 done
# Image 46 done
# Image 47 done
# Image 48 done
# Image 49 done
# Image 50 done
# Image 51 done
# Image 52 done
# Image 53 done
# Image 54 done
# Image 55 done
# Image 56 done
# Image 57 done
# Image 58 done
# Image 59 done
# Image 60 done
# Image 61 done
# Image 62 done
# Image 63 done
# Image 64 done
# Image 65 done
# Image 66 done
# Image 67 done
# Image 68 done
# Image 69 done
# Image 70 done
# Image 71 done
# Image 72 done
# Image 73 done
# Image 74 done
# Image 75 done
# Image 76 done
# Image 77 done
# Image 78 done
# Image 79 done
# Image 80 done
# Image 81 done
# Image 82 done
# Image 83 done
# Image 84 done
# Image 85 done
# Image 86 done
# Image 87 done
# Image 88 done
# Image 89 done
# Image 90 done
# Image 91 done
# Image 92 done
# Image 93 done
# Image 94 done
# Image 95 done
# Image 96 done
# Image 97 done
# Image 98 done
# Image 99 done
# Image 100 done
# Image 101 done
# Image 102 done
# Image 103 done
# Image 104 done
# Image 105 done
# Image 106 done
# Image 107 done
# Image 108 done
# Image 109 done
# Image 110 done
# Image 111 done
# Image 112 done
# Image 113 done
# Image 114 done
# Image 115 done
# Image 116 done
# Image 117 done
# Image 118 done
# Image 119 done
# Image 120 done
# Image 121 done
# Image 122 done
# Image 123 done
# Image 124 done
# Image 125 done
# Image 126 done
# Image 127 done
# Image 128 done
# Image 129 done
# Image 130 done
# Image 131 done
# Image 132 done
# Image 133 done
# Image 134 done
# Image 135 done
# Image 136 done
# Image 137 done
# Image 138 done
# Image 139 done
# Image 140 done
# Image 141 done
# Image 142 done
# Image 143 done
# Image 144 done
# Image 145 done
# Image 146 done
# Image 147 done
# Image 148 done
# Image 149 done
# Image 150 done
# Image 151 done
# Image 152 done
# Image 153 done
# Image 154 done
# Image 155 done
# Image 156 done
# Image 157 done
# Image 158 done
# Image 159 done
# Image 160 done
# Image 161 done
# Image 162 done
# Image 163 done
# Image 164 done
# Image 165 done
# Image 166 done
# Image 167 done
# Image 168 done
# Image 169 done
# Image 170 done
# Image 171 done
# Image 172 done
# Image 173 done
# Image 174 done
# Image 175 done
# Image 176 done
# Image 177 done
# Image 178 done
# Image 179 done
# Image 180 done
# Image 181 done
# Image 182 done
# Image 183 done
# Image 184 done
# Image 185 done
# Image 186 done
# Image 187 done
# Image 188 done
# Image 189 done
# Image 190 done
# Image 191 done
# Image 192 done
# Image 193 done
# Image 194 done
# Image 195 done
# Image 196 done
# Image 197 done
# Image 198 done
# Image 199 done
# Image 200 done
# Image 201 done
# Image 202 done
# Image 203 done
# Image 204 done
# Image 205 done
# Image 206 done
# Image 207 done
# Image 208 done
# Image 209 done
# Image 210 done
# Image 211 done
# Image 212 done
# Image 213 done
# Image 214 done
# Image 215 done
# Image 216 done
# Image 217 done
# Image 218 done
# Image 219 done
# Image 220 done
# Image 221 done
# Image 222 done
# Image 223 done
# Image 224 done
# Image 225 done
# Image 226 done
# Image 227 done
# Image 228 done
# Image 229 done
# Image 230 done
# Image 231 done
# Image 232 done
# Image 233 done
# Image 234 done
# Image 235 done
# Image 236 done
# Image 237 done
# Image 238 done
# Image 239 done
# Image 240 done
# Image 241 done
# Image 242 done
# Image 243 done
# Image 244 done
# Image 245 done
# Image 246 done
# Image 247 done
# Image 248 done
# Image 249 done
# Image 250 done
# Image 251 done
# Image 252 done
# Image 253 done
# Image 254 done
# Image 255 done
# Image 256 done
# Image 257 done
# Image 258 done
# Image 259 done
# Image 260 done
# Image 261 done
# Image 262 done
# Image 263 done
# Image 264 done
# Image 265 done
# Image 266 done
# Image 267 done
# Image 268 done
# Image 269 done
# Image 270 done
# Image 271 done
# Image 272 done
# Image 273 done
# Image 274 done
# Image 275 done
# Image 276 done
# Image 277 done
# Image 278 done
# Image 279 done
# Image 280 done
# Image 281 done
# Image 282 done
# Image 283 done
# Image 284 done
# Image 285 done
# Image 286 done
# Image 287 done
# Image 288 done
# Image 289 done
# Image 290 done
# Image 291 done
# Image 292 done
# Image 293 done
# Image 294 done
# Image 295 done
# Image 296 done
# Image 297 done
# Image 298 done
# Image 299 done
# Image 300 done
# Image 301 done
# Image 302 done
# Image 303 done
# Image 304 done
# Image 305 done
# Image 306 done
# Image 307 done
# Image 308 done
# Image 309 done
# Image 310 done
# Image 311 done
# Image 312 done
# Image 313 done
# Image 314 done
# Image 315 done
# Image 316 done
# Image 317 done
# Image 318 done
# Image 319 done
# Image 320 done
# Image 321 done
# Image 322 done
# Image 323 done
# Image 324 done
# Image 325 done
# Image 326 done
# Image 327 done
# Image 328 done
# Image 329 done
# Image 330 done
# Image 331 done
# Image 332 done
# Image 333 done
# Image 334 done
# Image 335 done
# Image 336 done
# Image 337 done
# Image 338 done
# Image 339 done
# Image 340 done
# Image 341 done
# Image 342 done
# Image 343 done
# Image 344 done
# Image 345 done
# Image 346 done
# Image 347 done
# Image 348 done
# Image 349 done
# Image 350 done
# Image 351 done
# Image 352 done
# Image 353 done
# Image 354 done
# Image 355 done
# Image 356 done
# Image 357 done
# Image 358 done
# Image 359 done
# Image 360 done
# Image 361 done
# Image 362 done
# Image 363 done
# Image 364 done
# Image 365 done
# Image 366 done
# Image 367 done
# Image 368 done
# Image 369 done
# Image 370 done
# Image 371 done
# Image 372 done
# Image 373 done
# Image 374 done
# Image 375 done
# Image 376 done
# Image 377 done
# Image 378 done
# Image 379 done
# Image 380 done
# Image 381 done
# Image 382 done
# Image 383 done
# Image 384 done
# Image 385 done
# Image 386 done
# Image 387 done
# Image 388 done
# Image 389 done
# Image 390 done
# Image 391 done
# Image 392 done
# Image 393 done
# Image 394 done
# Image 395 done
# Image 396 done
# Image 397 done
# Image 398 done
# Image 399 done
# Image 400 done
# Image 401 done
# Image 402 done
# Image 403 done
# Image 404 done
# Image 405 done
# Image 406 done
# Image 407 done
# Image 408 done
# Image 409 done
# Image 410 done
# Image 411 done
# Image 412 done
# Image 413 done
# Image 414 done
# Image 415 done
# Image 416 done
# Image 417 done
# Image 418 done
# Image 419 done
# Image 420 done
# Image 421 done
# Image 422 done
# Image 423 done
# Image 424 done
# Image 425 done
# Image 426 done
# Image 427 done
# Image 428 done
# Image 429 done
# Image 430 done
# Image 431 done
# Image 432 done
# Image 433 done
# Image 434 done
# Image 435 done
# Image 436 done
# Image 437 done
# Image 438 done
# Image 439 done
# Image 440 done
# Image 441 done
# Image 442 done
# Image 443 done
# Image 444 done
# Image 445 done
# Image 446 done
# Image 447 done
# Image 448 done
# Image 449 done
# Image 450 done
# Image 451 done
# Image 452 done
# Image 453 done
# Image 454 done
# Image 455 done
# Image 456 done
# Image 457 done
# Image 458 done
# Image 459 done
# Image 460 done
# Image 461 done
# Image 462 done
# Image 463 done
# Image 464 done
# Image 465 done
# Image 466 done
# Image 467 done
# Image 468 done
# Image 469 done
# Image 470 done
# Image 471 done
# Image 472 done
# Image 473 done
# Image 474 done
# Image 475 done
# Image 476 done
# Image 477 done
# Image 478 done
# Image 479 done
# Image 480 done
# Image 481 done
# Image 482 done
# Image 483 done
# Image 484 done
# Image 485 done
# Image 486 done
# Image 487 done
# Image 488 done
# Image 489 done
# Image 490 done
# Image 491 done
# Image 492 done
# Image 493 done
# Image 494 done
# Image 495 done
# Image 496 done
# Image 497 done
# Image 498 done
# Image 499 done
# Image 500 done
# Image 501 done
# Image 502 done
# Image 503 done
# Image 504 done
# Image 505 done
# Image 506 done
# Image 507 done
# Image 508 done
# Image 509 done
# Image 510 done
# Image 511 done
# Image 512 done
# Image 513 done
# Image 514 done
# Image 515 done
# Image 516 done
# Image 517 done
# Image 518 done
# Image 519 done
# Image 520 done
# Image 521 done
# Image 522 done
# Image 523 done
# Image 524 done
# Image 525 done
# Image 526 done
# Image 527 done
# Image 528 done
# Image 529 done
# Image 530 done
# Image 531 done
# Image 532 done
# Image 533 done
# Image 534 done
# Image 535 done
# Image 536 done
# Image 537 done
# Image 538 done
# Image 539 done
# Image 540 done
# Image 541 done
# Image 542 done
# Image 543 done
# Image 544 done
# Image 545 done
# Image 546 done
# Image 547 done
# Image 548 done
# Image 549 done
# Image 550 done
# Image 551 done
# Image 552 done
# Image 553 done
# Image 554 done
# Image 555 done
# Image 556 done
# Image 557 done
# Image 558 done
# Image 559 done
# Image 560 done
# Image 561 done
# Image 562 done
# Image 563 done
# Image 564 done
# Image 565 done
# Image 566 done
# Image 567 done
# Image 568 done
# Image 569 done
# Image 570 done
# Image 571 done
# Image 572 done
# Image 573 done
# Image 574 done
# Image 575 done
# Image 576 done
# Image 577 done
# Image 578 done
# Image 579 done
# Image 580 done
# Image 581 done
# Image 582 done
# Image 583 done
# Image 584 done
# Image 585 done
# Image 586 done
# Image 587 done
# Image 588 done
# Image 589 done
# Image 590 done
# Image 591 done
# Image 592 done
# Image 593 done
# Image 594 done
# Image 595 done
# Image 596 done
# Image 597 done
# Image 598 done
# Image 599 done
# Image 600 done
# Image 601 done
# Image 602 done
# Image 603 done
# Image 604 done
# Image 605 done
# Image 606 done
# Image 607 done
# Image 608 done
# Image 609 done
# Image 610 done
# Image 611 done
# Image 612 done
# Image 613 done
# Image 614 done
# Image 615 done
# Image 616 done
# Image 617 done
# Image 618 done
# Image 619 done
# Image 620 done
# Image 621 done
# Image 622 done
# Image 623 done
# Image 624 done
# Image 625 done
# Image 626 done
# Image 627 done
# Image 628 done
# Image 629 done
# Image 630 done
# Image 631 done
# Image 632 done
# Image 633 done
# Image 634 done
# Image 635 done
# Image 636 done
# Image 637 done
# Image 638 done
# Image 639 done
# Image 640 done
# Image 641 done
# Image 642 done
# Image 643 done
# Image 644 done
# Image 645 done
# Image 646 done
# Image 647 done
# Image 648 done
# Image 649 done
# Image 650 done
# Image 651 done
# Image 652 done
# Image 653 done
# Image 654 done
# Image 655 done
# Image 656 done
# Image 657 done
# Image 658 done
# Image 659 done
# Image 660 done
# Image 661 done
# Image 662 done
# Image 663 done
# Image 664 done
# Image 665 done
# Image 666 done
# Image 667 done
# Image 668 done
# Image 669 done
# Image 670 done
# Image 671 done
# Image 672 done
# Image 673 done
# Image 674 done
# Image 675 done
# Image 676 done
# Image 677 done
# Image 678 done
# Image 679 done
# Image 680 done
# Image 681 done
# Image 682 done
# Image 683 done
# Image 684 done
# Image 685 done
# Image 686 done
# Image 687 done
# Image 688 done
# Image 689 done
# Image 690 done
# Image 691 done
# Image 692 done
# Image 693 done
# Image 694 done
# Image 695 done
# Image 696 done
# Image 697 done
# Image 698 done
# Image 699 done
# Image 700 done
# Image 701 done
# Image 702 done
# Image 703 done
# Image 704 done
# Image 705 done
# Image 706 done
# Image 707 done
# Image 708 done
# Image 709 done
# Image 710 done
# Image 711 done
# Image 712 done
# Image 713 done
# Image 714 done
# Image 715 done
# Image 716 done
# Image 717 done
# Image 718 done
# Image 719 done
# Image 720 done
# Image 721 done
# Image 722 done
# Image 723 done
# Image 724 done
# Image 725 done
# Image 726 done
# Image 727 done
# Image 728 done
# Image 729 done
# Image 730 done
# Image 731 done
# Image 732 done
# Image 733 done
# Image 734 done
# Image 735 done
# Image 736 done
# Image 737 done
# Image 738 done
# Image 739 done
# Image 740 done
# Image 741 done
# Image 742 done
# Image 743 done
# Image 744 done
# Image 745 done
# Image 746 done
# Image 747 done
# Image 748 done
# Image 749 done
# Image 750 done
# Image 751 done
# Image 752 done
# Image 753 done
# Image 754 done
# Image 755 done
# Image 756 done
# Image 757 done
# Image 758 done
# Image 759 done
# Image 760 done
# Image 761 done
# Image 762 done
# Image 763 done
# Image 764 done
# Image 765 done
# Image 766 done
# Image 767 done
# Image 768 done
# Image 769 done
# Image 770 done
# Image 771 done
# Image 772 done
# Image 773 done
# Image 774 done
# Image 775 done
# Image 776 done
# Image 777 done
# Image 778 done
# Image 779 done
# Image 780 done
# Image 781 done
# Image 782 done
# Image 783 done
# Image 784 done
# Image 785 done
# Image 786 done
# Image 787 done
# Image 788 done
# Image 789 done
# Image 790 done
# Image 791 done
# Image 792 done
# Image 793 done
# Image 794 done
# Image 795 done
# Image 796 done
# Image 797 done
# Image 798 done
# Image 799 done
# Image 800 done
# Image 801 done
# Image 802 done
# Image 803 done
# Image 804 done
# Image 805 done
# Image 806 done
# Image 807 done
# Image 808 done
# Image 809 done
# Image 810 done
# Image 811 done
# Image 812 done
# Image 813 done
# Image 814 done
# Image 815 done
# Image 816 done
# Image 817 done
# Image 818 done
# Image 819 done
# Image 820 done
# Image 821 done
# Image 822 done
# Image 823 done
# Image 824 done
# Image 825 done
# Image 826 done
# Image 827 done
# Image 828 done
# Image 829 done
# Image 830 done
# Image 831 done
# Image 832 done
# Image 833 done
# Image 834 done
# Image 835 done
# Image 836 done
# Image 837 done
# Image 838 done
# Image 839 done
# Image 840 done
# Image 841 done
# Image 842 done
# Image 843 done
# Image 844 done
# Image 845 done
# Image 846 done
# Image 847 done
# Image 848 done
# Image 849 done
# Image 850 done
# Image 851 done
# Image 852 done
# Image 853 done
# Image 854 done
# Image 855 done
# Image 856 done
# Image 857 done
# Image 858 done
# Image 859 done
# Image 860 done
# Image 861 done
# Image 862 done
# Image 863 done
# Image 864 done
# Image 865 done
# Image 866 done
# Image 867 done
# Image 868 done
# Image 869 done
# Image 870 done
# Image 871 done
# Image 872 done
# Image 873 done
# Image 874 done
# Image 875 done
# Image 876 done
# Image 877 done
# Image 878 done
# Image 879 done
# Image 880 done
# Image 881 done
# Image 882 done
# Image 883 done
# Image 884 done
# Image 885 done
# Image 886 done
# Image 887 done
# Image 888 done
# Image 889 done
# Image 890 done
# Image 891 done
# Image 892 done
# Image 893 done
# Image 894 done
# Image 895 done
# Image 896 done
# Image 897 done
# Image 898 done
# Image 899 done
# Image 900 done
# Image 901 done
# Image 902 done
# Image 903 done
# Image 904 done
# Image 905 done
# Image 906 done
# Image 907 done
# Image 908 done
# Image 909 done
# Image 910 done
# Image 911 done
# Image 912 done
# Image 913 done
# Image 914 done
# Image 915 done
# Image 916 done
# Image 917 done
# Image 918 done
# Image 919 done
# Image 920 done
# Image 921 done
# Image 922 done
# Image 923 done
# Image 924 done
# Image 925 done
# Image 926 done
# Image 927 done
# Image 928 done
# Image 929 done
# Image 930 done
# Image 931 done
# Image 932 done
# Image 933 done
# Image 934 done
# Image 935 done
# Image 936 done
# Image 937 done
# Image 938 done
# Image 939 done
# Image 940 done
# Image 941 done
# Image 942 done
# Image 943 done
# Image 944 done
# Image 945 done
# Image 946 done
# Image 947 done
# Image 948 done
# Image 949 done
# Image 950 done
# Image 951 done
# Image 952 done
# Image 953 done
# Image 954 done
# Image 955 done
# Image 956 done
# Image 957 done
# Image 958 done
# Image 959 done
# Image 960 done
# Image 961 done
# Image 962 done
# Image 963 done
# Image 964 done
# Image 965 done
# Image 966 done
# Image 967 done
# Image 968 done
# Image 969 done
# Image 970 done
# Image 971 done
# Image 972 done
# Image 973 done
# Image 974 done
# Image 975 done
# Image 976 done
# Image 977 done
# Image 978 done
# Image 979 done
# Image 980 done
# Image 981 done
# Image 982 done
# Image 983 done
# Image 984 done
# Image 985 done
# Image 986 done
# Image 987 done
# Image 988 done
# Image 989 done
# Image 990 done
# Image 991 done
# Image 992 done
# Image 993 done
# Image 994 done
# Image 995 done
# Image 996 done
# Image 997 done
# Image 998 done
# Image 999 done
# Image 1000 done
# Image 1001 done
# Image 1002 done
# Image 1003 done
# Image 1004 done
# Image 1005 done
# Image 1006 done
# Image 1007 done
# Image 1008 done
# Image 1009 done
# Image 1010 done
# Image 1011 done
# Image 1012 done
# Image 1013 done
# Image 1014 done
# Image 1015 done
# Image 1016 done
# Image 1017 done
# Image 1018 done
# Image 1019 done
# Image 1020 done
# Image 1021 done
# Image 1022 done
# Image 1023 done
# Image 1024 done
# Image 1025 done
# Image 1026 done
# Image 1027 done
# Image 1028 done
# Image 1029 done
# Image 1030 done
# Image 1031 done
# Image 1032 done
# Image 1033 done
# Image 1034 done
# Image 1035 done
# Image 1036 done
# Image 1037 done
# Image 1038 done
# Image 1039 done
# Image 1040 done
# Image 1041 done
# Image 1042 done
# Image 1043 done
# Image 1044 done
# Image 1045 done
# Image 1046 done
# Image 1047 done
# Image 1048 done
# Image 1049 done
# Image 1050 done
# Image 1051 done
# Image 1052 done
# Image 1053 done
# Image 1054 done
# Image 1055 done
# Image 1056 done
# Image 1057 done
# Image 1058 done
# Image 1059 done
# Image 1060 done
# Image 1061 done
# Image 1062 done
# Image 1063 done
# Image 1064 done
# Image 1065 done
# Image 1066 done
# Image 1067 done
# Image 1068 done
# Image 1069 done
# Image 1070 done
# Image 1071 done
# Image 1072 done
# Image 1073 done
# Image 1074 done
# Image 1075 done
# Image 1076 done
# Image 1077 done
# Image 1078 done
# Image 1079 done
# Image 1080 done
# Image 1081 done
# Image 1082 done
# Image 1083 done
# Image 1084 done
# Image 1085 done
# Image 1086 done
# Image 1087 done
# Image 1088 done
# Image 1089 done
# Image 1090 done
# Image 1091 done
# Image 1092 done
# Image 1093 done
# Image 1094 done
# Image 1095 done
# Image 1096 done
# Image 1097 done
# Image 1098 done
# Image 1099 done
# Image 1100 done
# Image 1101 done
# Image 1102 done
# Image 1103 done
# Image 1104 done
# Image 1105 done
# Image 1106 done
# Image 1107 done
# Image 1108 done
# Image 1109 done
# Image 1110 done
# Image 1111 done
# Image 1112 done
# Image 1113 done
# Image 1114 done
# Image 1115 done
# Image 1116 done
# Image 1117 done
# Image 1118 done
# Image 1119 done
# Image 1120 done
# Image 1121 done
# Image 1122 done
# Image 1123 done
# Image 1124 done
# Image 1125 done
# Image 1126 done
# Image 1127 done
# Image 1128 done
# Image 1129 done
# Image 1130 done
# Image 1131 done
# Image 1132 done
# Image 1133 done
# Image 1134 done
# Image 1135 done
# Image 1136 done
# Image 1137 done
# Image 1138 done
# Image 1139 done
# Image 1140 done
# Image 1141 done
# Image 1142 done
# Image 1143 done
# Image 1144 done
# Image 1145 done
# Image 1146 done
# Image 1147 done
# Image 1148 done
# Image 1149 done
# Image 1150 done
# Image 1151 done
# Image 1152 done
# Image 1153 done
# Image 1154 done
# Image 1155 done
# Image 1156 done
# Image 1157 done
# Image 1158 done
# Image 1159 done
# Image 1160 done
# Image 1161 done
# Image 1162 done
# Image 1163 done
# Image 1164 done
# Image 1165 done
# Image 1166 done
# Image 1167 done
# Image 1168 done
# Image 1169 done
# Image 1170 done
# Image 1171 done
# Image 1172 done
# Image 1173 done
# Image 1174 done
# Image 1175 done
# Image 1176 done
# Image 1177 done
# Image 1178 done
# Image 1179 done
# Image 1180 done
# Image 1181 done
# Image 1182 done
# Image 1183 done
# Image 1184 done
# Image 1185 done
# Image 1186 done
# Image 1187 done
# Image 1188 done
# Image 1189 done
# Image 1190 done
# Image 1191 done
# Image 1192 done
# Image 1193 done
# Image 1194 done
# Image 1195 done
# Image 1196 done
# Image 1197 done
# Image 1198 done
# Image 1199 done
# Image 1200 done
# Image 1201 done
# Image 1202 done
# Image 1203 done
# Image 1204 done
# Image 1205 done
# Image 1206 done
# Image 1207 done
# Image 1208 done
# Image 1209 done
# Image 1210 done
# Image 1211 done
# Image 1212 done
# Image 1213 done
# Image 1214 done
# Image 1215 done
# Image 1216 done
# Image 1217 done
# Image 1218 done
# Image 1219 done
# Image 1220 done
# Image 1221 done
# Image 1222 done
# Image 1223 done
# Image 1224 done
# Image 1225 done
# Image 1226 done
# Image 1227 done
# Image 1228 done
# Image 1229 done
# Image 1230 done
# Image 1231 done
# Image 1232 done
# Image 1233 done
# Image 1234 done
# Image 1235 done
# Image 1236 done
# Image 1237 done
# Image 1238 done
# Image 1239 done
# Image 1240 done
# Image 1241 done
# Image 1242 done
# Image 1243 done
# Image 1244 done
# Image 1245 done
# Image 1246 done
# Image 1247 done
# Image 1248 done
# Image 1249 done
# Image 1250 done
# Image 1251 done
# Image 1252 done
# Image 1253 done
# Image 1254 done
# Image 1255 done
# Image 1256 done
# Image 1257 done
# Image 1258 done
# Image 1259 done
# Image 1260 done
# Image 1261 done
# Image 1262 done
# Image 1263 done
# Image 1264 done
# Image 1265 done
# Image 1266 done
# Image 1267 done
# Image 1268 done
# Image 1269 done
# Image 1270 done
# Image 1271 done
# Image 1272 done
# Image 1273 done
# Image 1274 done
# Image 1275 done
# Image 1276 done
# Image 1277 done
# Image 1278 done
# Image 1279 done
# Image 1280 done
# Image 1281 done
# Image 1282 done
# Image 1283 done
# Image 1284 done
# Image 1285 done
# Image 1286 done
# Image 1287 done
# Image 1288 done
# Image 1289 done
# Image 1290 done
# Image 1291 done
# Image 1292 done
# Image 1293 done
# Image 1294 done
# Image 1295 done
# Image 1296 done
# Image 1297 done
# Image 1298 done
# Image 1299 done
# Image 1300 done
# Image 1301 done
# Image 1302 done
# Image 1303 done
# Image 1304 done
# Image 1305 done
# Image 1306 done
# Image 1307 done
# Image 1308 done
# Image 1309 done
# Image 1310 done
# Image 1311 done
# Image 1312 done
# Image 1313 done
# Image 1314 done
# Image 1315 done
# Image 1316 done
# Image 1317 done
# Image 1318 done
# Image 1319 done
# Image 1320 done
# Image 1321 done
# Image 1322 done
# Image 1323 done
# Image 1324 done
# Image 1325 done
# Image 1326 done
# Image 1327 done
# Image 1328 done
# Image 1329 done
# Image 1330 done
# Image 1331 done
# Image 1332 done
# Image 1333 done
# Image 1334 done
# Image 1335 done
# Image 1336 done
# Image 1337 done
# Image 1338 done
# Image 1339 done
# Image 1340 done
# Image 1341 done
# Image 1342 done
# Image 1343 done
# Image 1344 done
# Image 1345 done
# Image 1346 done
# Image 1347 done
# Image 1348 done
# Image 1349 done
# Image 1350 done
# Image 1351 done
# Image 1352 done
# Image 1353 done
# Image 1354 done
# Image 1355 done
# Image 1356 done
# Image 1357 done
# Image 1358 done
# Image 1359 done
# Image 1360 done
# Image 1361 done
# Image 1362 done
# Image 1363 done
# Image 1364 done
# Image 1365 done
# Image 1366 done
# Image 1367 done
# Image 1368 done
# Image 1369 done
# Image 1370 done
# Image 1371 done
# Image 1372 done
# Image 1373 done
# Image 1374 done
# Image 1375 done
# Image 1376 done
# Image 1377 done
# Image 1378 done
# Image 1379 done
# Image 1380 done
# Image 1381 done
# Image 1382 done
# Image 1383 done
# Image 1384 done
# Image 1385 done
# Image 1386 done
# Image 1387 done
# Image 1388 done
# Image 1389 done
# Image 1390 done
# Image 1391 done
# Image 1392 done
# Image 1393 done
# Image 1394 done
# Image 1395 done
# Image 1396 done
# Image 1397 done
# Image 1398 done
# Image 1399 done
# Image 1400 done
# Image 1401 done
# Image 1402 done
# Image 1403 done
# Image 1404 done
# Image 1405 done
# Image 1406 done
# Image 1407 done
# Image 1408 done
# Image 1409 done
# Image 1410 done
# Image 1411 done
# Image 1412 done
# Image 1413 done
# Image 1414 done
# Image 1415 done
# Image 1416 done
# Image 1417 done
# Image 1418 done
# Image 1419 done
# Image 1420 done
# Image 1421 done
# Image 1422 done
# Image 1423 done
# Image 1424 done
# Image 1425 done
# Image 1426 done
# Image 1427 done
# Image 1428 done
# Image 1429 done
# Image 1430 done
# Image 1431 done
# Image 1432 done
# Image 1433 done
# Image 1434 done
# Image 1435 done
# Image 1436 done
# Image 1437 done
# Image 1438 done
# Image 1439 done
# Image 1440 done
# Image 1441 done
# Image 1442 done
# Image 1443 done
# Image 1444 done
# Image 1445 done
# Image 1446 done
# Image 1447 done
# Image 1448 done
# Image 1449 done
# Image 1450 done
# Image 1451 done
# Image 1452 done
# Image 1453 done
# Image 1454 done
# Image 1455 done
# Image 1456 done
# Image 1457 done
# Image 1458 done
# Image 1459 done
# Image 1460 done
# Image 1461 done
# Image 1462 done
# Image 1463 done
# Image 1464 done
# Image 1465 done
# Image 1466 done
# Image 1467 done
# Image 1468 done
# Image 1469 done
# Image 1470 done
# Image 1471 done
# Image 1472 done
# Image 1473 done
# Image 1474 done
# Image 1475 done
# Image 1476 done
# Image 1477 done
# Image 1478 done
# Image 1479 done
# Image 1480 done
# Image 1481 done
# Image 1482 done
# Image 1483 done
# Image 1484 done
# Image 1485 done
# Image 1486 done
# Image 1487 done
# Image 1488 done
# Image 1489 done
# Image 1490 done
# Image 1491 done
# Image 1492 done
# Image 1493 done
# Image 1494 done
# Image 1495 done
# Image 1496 done
# Image 1497 done
# Image 1498 done
# Image 1499 done
# Image 1500 done
# Image 1501 done
# Image 1502 done
# Image 1503 done
# Image 1504 done
# Image 1505 done
# Image 1506 done
# Image 1507 done
# Image 1508 done
# Image 1509 done
# Image 1510 done
# Image 1511 done
# Image 1512 done
# Image 1513 done
# Image 1514 done
# Image 1515 done
# Image 1516 done
# Image 1517 done
# Image 1518 done
# Image 1519 done
# Image 1520 done
# Image 1521 done
# Image 1522 done
# Image 1523 done
# Image 1524 done
# Image 1525 done
# Image 1526 done
# Image 1527 done
# Image 1528 done
# Image 1529 done
# Image 1530 done
# Image 1531 done
# Image 1532 done
# Image 1533 done
# Image 1534 done
# Image 1535 done
# Image 1536 done
# Image 1537 done
# Image 1538 done
# Image 1539 done
# Image 1540 done
# Image 1541 done
# Image 1542 done
# Image 1543 done
# Image 1544 done
# Image 1545 done
# Image 1546 done
# Image 1547 done
# Image 1548 done
# Image 1549 done
# Image 1550 done
# Image 1551 done
# Image 1552 done
# Image 1553 done
# Image 1554 done
# Image 1555 done
# Image 1556 done
# Image 1557 done
# Image 1558 done
# Image 1559 done
# Image 1560 done
# Image 1561 done
# Image 1562 done
# Image 1563 done
# Image 1564 done
# Image 1565 done
# Image 1566 done
# Image 1567 done
# Image 1568 done
# Image 1569 done
# Image 1570 done
# Image 1571 done
# Image 1572 done
# Image 1573 done
# Image 1574 done
# Image 1575 done
# Image 1576 done
# Image 1577 done
# Image 1578 done
# Image 1579 done
# Image 1580 done
# Image 1581 done
# Image 1582 done
# Image 1583 done
# Image 1584 done
# Image 1585 done
# Image 1586 done
# Image 1587 done
# Image 1588 done
# Image 1589 done
# Image 1590 done
# Image 1591 done
# Image 1592 done
# Image 1593 done
# Image 1594 done
# Image 1595 done
# Image 1596 done
# Image 1597 done
# Image 1598 done
# Image 1599 done
# Image 1600 done
# Image 1601 done
# Image 1602 done
# Image 1603 done
# Image 1604 done
# Image 1605 done
# Image 1606 done
# Image 1607 done
# Image 1608 done
# Image 1609 done
# Image 1610 done
# Image 1611 done
# Image 1612 done
# Image 1613 done
# Image 1614 done
# Image 1615 done
# Image 1616 done
# Image 1617 done
# Image 1618 done
# Image 1619 done
# Image 1620 done
# Image 1621 done
# Image 1622 done
# Image 1623 done
# Image 1624 done
# Image 1625 done
# Image 1626 done
# Image 1627 done
# Image 1628 done
# Image 1629 done
# Image 1630 done
# Image 1631 done
# Image 1632 done
# Image 1633 done
# Image 1634 done
# Image 1635 done
# Image 1636 done
# Image 1637 done
# Image 1638 done
# Image 1639 done
# Image 1640 done
# Image 1641 done
# Image 1642 done
# Image 1643 done
# Image 1644 done
# Image 1645 done
# Image 1646 done
# Image 1647 done
# Image 1648 done
# Image 1649 done
# Image 1650 done
# Image 1651 done
# Image 1652 done
# Image 1653 done
# Image 1654 done
# Image 1655 done
# Image 1656 done
# Image 1657 done
# Image 1658 done
# Image 1659 done
# Image 1660 done
# Image 1661 done
# Image 1662 done
# Image 1663 done
# Image 1664 done
# Image 1665 done
# Image 1666 done
# Image 1667 done
# Image 1668 done
# Image 1669 done
# Image 1670 done
# Image 1671 done
# Image 1672 done
# Image 1673 done
# Image 1674 done
# Image 1675 done
# Image 1676 done
# Image 1677 done
# Image 1678 done
# Image 1679 done
# Image 1680 done
# Image 1681 done
# Image 1682 done
# Image 1683 done
# Image 1684 done
# Image 1685 done
# Image 1686 done
# Image 1687 done
# Image 1688 done
# Image 1689 done
# Image 1690 done
# Image 1691 done
# Image 1692 done
# Image 1693 done
# Image 1694 done
# Image 1695 done
# Image 1696 done
# Image 1697 done
# Image 1698 done
# Image 1699 done
# Image 1700 done
# Image 1701 done
# Image 1702 done
# Image 1703 done
# Image 1704 done
# Image 1705 done
# Image 1706 done
# Image 1707 done
# Image 1708 done
# Image 1709 done
# Image 1710 done
# Image 1711 done
# Image 1712 done
# Image 1713 done
# Image 1714 done
# Image 1715 done
# Image 1716 done
# Image 1717 done
# Image 1718 done
# Image 1719 done
# Image 1720 done
# Image 1721 done
# Image 1722 done
# Image 1723 done
# Image 1724 done
# Image 1725 done
# Image 1726 done
# Image 1727 done
# Image 1728 done
# Image 1729 done
# Image 1730 done
# Image 1731 done
# Image 1732 done
# Image 1733 done
# Image 1734 done
# Image 1735 done
# Image 1736 done
# Image 1737 done
# Image 1738 done
# Image 1739 done
# Image 1740 done
# Image 1741 done
# Image 1742 done
# Image 1743 done
# Image 1744 done
# Image 1745 done
# Image 1746 done
# Image 1747 done
# Image 1748 done
# Image 1749 done
# Image 1750 done
# Image 1751 done
# Image 1752 done
# Image 1753 done
# Image 1754 done
# Image 1755 done
# Image 1756 done
# Image 1757 done
# Image 1758 done
# Image 1759 done
# Image 1760 done
# Image 1761 done
# Image 1762 done
# Image 1763 done
# Image 1764 done
# Image 1765 done
# Image 1766 done
# Image 1767 done
# Image 1768 done
# Image 1769 done
# Image 1770 done
# Image 1771 done
# Image 1772 done
# Image 1773 done
# Image 1774 done
# Image 1775 done
# Image 1776 done
# Image 1777 done
# Image 1778 done
# Image 1779 done
# Image 1780 done
# Image 1781 done
# Image 1782 done
# Image 1783 done
# Image 1784 done
# Image 1785 done
# Image 1786 done
# Image 1787 done
# Image 1788 done
# Image 1789 done
# Image 1790 done
# Image 1791 done
# Image 1792 done
# Image 1793 done
# Image 1794 done
# Image 1795 done
# Image 1796 done
# Image 1797 done
# Image 1798 done
# Image 1799 done
# Image 1800 done
# Image 1801 done
# Image 1802 done
# Image 1803 done
# Image 1804 done
# Image 1805 done
# Image 1806 done
# Image 1807 done
# Image 1808 done
# Image 1809 done
# Image 1810 done
# Image 1811 done
# Image 1812 done
# Image 1813 done
# Image 1814 done
# Image 1815 done
# Image 1816 done
# Image 1817 done
# Image 1818 done
# Image 1819 done
# Image 1820 done
# Image 1821 done
# Image 1822 done
# Image 1823 done
# Image 1824 done
# Image 1825 done
# Image 1826 done
# Image 1827 done
# Image 1828 done
# Image 1829 done
# Image 1830 done
# Image 1831 done
# Image 1832 done
# Image 1833 done
# Image 1834 done
# Image 1835 done
# Image 1836 done
# Image 1837 done
# Image 1838 done
# Image 1839 done
# Image 1840 done
# Image 1841 done
# Image 1842 done
# Image 1843 done
# Image 1844 done
# Image 1845 done
# Image 1846 done
# Image 1847 done
# Image 1848 done
# Image 1849 done
# Image 1850 done
# Image 1851 done
# Image 1852 done
# Image 1853 done
# Image 1854 done
# Image 1855 done
# Image 1856 done
# Image 1857 done
# Image 1858 done
# Image 1859 done
# Image 1860 done
# Image 1861 done
# Image 1862 done
# Image 1863 done
# Image 1864 done
# Image 1865 done
# Image 1866 done
# Image 1867 done
# Image 1868 done
# Image 1869 done
# Image 1870 done
# Image 1871 done
# Image 1872 done
# Image 1873 done
# Image 1874 done
# Image 1875 done
# Image 1876 done
# Image 1877 done
# Image 1878 done
# Image 1879 done
# Image 1880 done
# Image 1881 done
# Image 1882 done
# Image 1883 done
# Image 1884 done
# Image 1885 done
# Image 1886 done
# Image 1887 done
# Image 1888 done
# Image 1889 done
# Image 1890 done
# Image 1891 done
# Image 1892 done
# Image 1893 done
# Image 1894 done
# Image 1895 done
# Image 1896 done
# Image 1897 done
# Image 1898 done
# Image 1899 done
# Image 1900 done
# Image 1901 done
# Image 1902 done
# Image 1903 done
# Image 1904 done
# Image 1905 done
# Image 1906 done
# Image 1907 done
# Image 1908 done
# Image 1909 done
# Image 1910 done
# Image 1911 done
# Image 1912 done
# Image 1913 done
# Image 1914 done
# Image 1915 done
# Image 1916 done
# Image 1917 done
# Image 1918 done
# Image 1919 done
# Image 1920 done
# Image 1921 done
# Image 1922 done
# Image 1923 done
# Image 1924 done
# Image 1925 done
# Image 1926 done
# Image 1927 done
# Image 1928 done
# Image 1929 done
# Image 1930 done
# Image 1931 done
# Image 1932 done
# Image 1933 done
# Image 1934 done
# Image 1935 done
# Image 1936 done
# Image 1937 done
# Image 1938 done
# Image 1939 done
# Image 1940 done
# Image 1941 done
# Image 1942 done
# Image 1943 done
# Image 1944 done
# Image 1945 done
# Image 1946 done
# Image 1947 done
# Image 1948 done
# Image 1949 done
# Image 1950 done
# Image 1951 done
# Image 1952 done
# Image 1953 done
# Image 1954 done
# Image 1955 done
# Image 1956 done
# Image 1957 done
# Image 1958 done
# Image 1959 done
# Image 1960 done
# Image 1961 done
# Image 1962 done
# Image 1963 done
# Image 1964 done
# Image 1965 done
# Image 1966 done
# Image 1967 done
# Image 1968 done
# Image 1969 done
# Image 1970 done
# Image 1971 done
# Image 1972 done
# Image 1973 done
# Image 1974 done
# Image 1975 done
# Image 1976 done
# Image 1977 done
# Image 1978 done
# Image 1979 done
# Image 1980 done
# Image 1981 done
# Image 1982 done
# Image 1983 done
# Image 1984 done
# Image 1985 done
# Image 1986 done
# Image 1987 done
# Image 1988 done
# Image 1989 done
# Image 1990 done
# Image 1991 done
# Image 1992 done
# Image 1993 done
# Image 1994 done
# Image 1995 done
# Image 1996 done
# Image 1997 done
# Image 1998 done
# Image 1999 done
# Image 2000 done
# Image 2001 done
# Image 2002 done
# Image 2003 done
# Image 2004 done
# Image 2005 done
# Image 2006 done
# Image 2007 done
# Image 2008 done
# Image 2009 done
# Image 2010 done
# Image 2011 done
# Image 2012 done
# Image 2013 done
# Image 2014 done
# Image 2015 done
# Image 2016 done
# Image 2017 done
# Image 2018 done
# Image 2019 done
# Image 2020 done
# Image 2021 done
# Image 2022 done
# Image 2023 done
# Image 2024 done
# Image 2025 done
# Image 2026 done
# Image 2027 done
# Image 2028 done
# Image 2029 done
# Image 2030 done
# Image 2031 done
# Image 2032 done
# Image 2033 done
# Image 2034 done
# Image 2035 done
# Image 2036 done
# Image 2037 done
# Image 2038 done
# Image 2039 done
# Image 2040 done
# Image 2041 done
# Image 2042 done
# Image 2043 done
# Image 2044 done
# Image 2045 done
# Image 2046 done
# Image 2047 done
# Image 2048 done
# Image 2049 done
# Image 2050 done
# Image 2051 done
# Image 2052 done
# Image 2053 done
# Image 2054 done
# Image 2055 done
# Image 2056 done
# Image 2057 done
# Image 2058 done
# Image 2059 done
# Image 2060 done
# Image 2061 done
# Image 2062 done
# Image 2063 done
# Image 2064 done
# Image 2065 done
# Image 2066 done
# Image 2067 done
# Image 2068 done
# Image 2069 done
# Image 2070 done
# Image 2071 done
# Image 2072 done
# Image 2073 done
# Image 2074 done
# Image 2075 done
# Image 2076 done
# Image 2077 done
# Image 2078 done
# Image 2079 done
# Image 2080 done
# Image 2081 done
# Image 2082 done
# Image 2083 done
# Image 2084 done
# Image 2085 done
# Image 2086 done
# Image 2087 done
# Image 2088 done
# Image 2089 done
# Image 2090 done
# Image 2091 done
# Image 2092 done
# Image 2093 done
# Image 2094 done
# Image 2095 done
# Image 2096 done
# Image 2097 done
# Image 2098 done
# Image 2099 done
# Image 2100 done
# Image 2101 done
# Image 2102 done
# Image 2103 done
# Image 2104 done
# Image 2105 done
# Image 2106 done
# Image 2107 done
# Image 2108 done
# Image 2109 done
# Image 2110 done
# Image 2111 done
# Image 2112 done
# Image 2113 done
# Image 2114 done
# Image 2115 done
# Image 2116 done
# Image 2117 done
# Image 2118 done
# Image 2119 done
# Image 2120 done
# Image 2121 done
# Image 2122 done
# Image 2123 done
# Image 2124 done
# Image 2125 done
# Image 2126 done
# Image 2127 done
# Image 2128 done
# Image 2129 done
# Image 2130 done
# Image 2131 done
# Image 2132 done
# Image 2133 done
# Image 2134 done
# Image 2135 done
# Image 2136 done
# Image 2137 done
# Image 2138 done
# Image 2139 done
# Image 2140 done
# Image 2141 done
# Image 2142 done
# Image 2143 done
# Image 2144 done
# Image 2145 done
# Image 2146 done
# Image 2147 done
# Image 2148 done
# Image 2149 done
# Image 2150 done
# Image 2151 done
# Image 2152 done
# Image 2153 done
# Image 2154 done
# Image 2155 done
# Image 2156 done
# Image 2157 done
# Image 2158 done
# Image 2159 done
# Image 2160 done
# Image 2161 done
# Image 2162 done
# Image 2163 done
# Image 2164 done
# Image 2165 done
# Image 2166 done
# Image 2167 done
# Image 2168 done
# Image 2169 done
# Image 2170 done
# Image 2171 done
# Image 2172 done
# Image 2173 done
# Image 2174 done
# Image 2175 done
# Image 2176 done
# Image 2177 done
# Image 2178 done
# Image 2179 done
# Image 2180 done
# Image 2181 done
# Image 2182 done
# Image 2183 done
# Image 2184 done
# Image 2185 done
# Image 2186 done
# Image 2187 done
# Image 2188 done
# Image 2189 done
# Image 2190 done
# Image 2191 done
# Image 2192 done
# Image 2193 done
# Image 2194 done
# Image 2195 done
# Image 2196 done
# Image 2197 done
# Image 2198 done
# Image 2199 done
# Image 2200 done
# Image 2201 done
# Image 2202 done
# Image 2203 done
# Image 2204 done
# Image 2205 done
# Image 2206 done
# Image 2207 done
# Image 2208 done
# Image 2209 done
# Image 2210 done
# Image 2211 done
# Image 2212 done
# Image 2213 done
# Image 2214 done
# Image 2215 done
# Image 2216 done
# Image 2217 done
# Image 2218 done
# Image 2219 done
# Image 2220 done
# Image 2221 done
# Image 2222 done
# Image 2223 done
# Image 2224 done
# Image 2225 done
# Image 2226 done
# Image 2227 done
# Image 2228 done
# Image 2229 done
# Image 2230 done
# Image 2231 done
# Image 2232 done
# Image 2233 done
# Image 2234 done
# Image 2235 done
# Image 2236 done
# Image 2237 done
# Image 2238 done
# Image 2239 done
# Image 2240 done
# Image 2241 done
# Image 2242 done
# Image 2243 done
# Image 2244 done
# Image 2245 done
# Image 2246 done
# Image 2247 done
# Image 2248 done
# Image 2249 done
# Image 2250 done
# Image 2251 done
# Image 2252 done
# Image 2253 done
# Image 2254 done
# Image 2255 done
# Image 2256 done
# Image 2257 done
# Image 2258 done
# Image 2259 done
# Image 2260 done
# Image 2261 done
# Image 2262 done
# Image 2263 done
# Image 2264 done
# Image 2265 done
# Image 2266 done
# Image 2267 done
# Image 2268 done
# Image 2269 done
# Image 2270 done
# Image 2271 done
# Image 2272 done
# Image 2273 done
# Image 2274 done
# Image 2275 done
# Image 2276 done
# Image 2277 done
# Image 2278 done
# Image 2279 done
# Image 2280 done
# Image 2281 done
# Image 2282 done
# Image 2283 done
# Image 2284 done
# Image 2285 done
# Image 2286 done
# Image 2287 done
# Image 2288 done
# Image 2289 done
# Image 2290 done
# Image 2291 done
# Image 2292 done
# Image 2293 done
# Image 2294 done
# Image 2295 done
# Image 2296 done
# Image 2297 done
# Image 2298 done
# Image 2299 done
# Image 2300 done
# Image 2301 done
# Image 2302 done
# Image 2303 done
# Image 2304 done
# Image 2305 done
# Image 2306 done
# Image 2307 done
# Image 2308 done
# Image 2309 done
# Image 2310 done
# Image 2311 done
# Image 2312 done
# Image 2313 done
# Image 2314 done
# Image 2315 done
# Image 2316 done
# Image 2317 done
# Image 2318 done
# Image 2319 done
# Image 2320 done
# Image 2321 done
# Image 2322 done
# Image 2323 done
# Image 2324 done
# Image 2325 done
# Image 2326 done
# Image 2327 done
# Image 2328 done
# Image 2329 done
# Image 2330 done
# Image 2331 done
# Image 2332 done
# Image 2333 done
# Image 2334 done
# Image 2335 done
# Image 2336 done
# Image 2337 done
# Image 2338 done
# Image 2339 done
# Image 2340 done
# Image 2341 done
# Image 2342 done
# Image 2343 done
# Image 2344 done
# Image 2345 done
# Image 2346 done
# Image 2347 done
# Image 2348 done
# Image 2349 done
# Image 2350 done
# Image 2351 done
# Image 2352 done
# Image 2353 done
# Image 2354 done
# Image 2355 done
# Image 2356 done
# Image 2357 done
# Image 2358 done
# Image 2359 done
# Image 2360 done
# Image 2361 done
# Image 2362 done
# Image 2363 done
# Image 2364 done
# Image 2365 done
# Image 2366 done
# Image 2367 done
# Image 2368 done
# Image 2369 done
# Image 2370 done
# Image 2371 done
# Image 2372 done
# Image 2373 done
# Image 2374 done
# Image 2375 done
# Image 2376 done
# Image 2377 done
# Image 2378 done
# Image 2379 done
# Image 2380 done
# Image 2381 done
# Image 2382 done
# Image 2383 done
# Image 2384 done
# Image 2385 done
# Image 2386 done
# Image 2387 done
# Image 2388 done
# Image 2389 done
# Image 2390 done
# Image 2391 done
# Image 2392 done
# Image 2393 done
# Image 2394 done
# Image 2395 done
# Image 2396 done
# Image 2397 done
# Image 2398 done
# Image 2399 done
# Image 2400 done
# Image 2401 done
# Image 2402 done
# Image 2403 done
# Image 2404 done
# Image 2405 done
# Image 2406 done
# Image 2407 done
# Image 2408 done
# Image 2409 done
# Image 2410 done
# Image 2411 done
# Image 2412 done
# Image 2413 done
# Image 2414 done
# Image 2415 done
# Image 2416 done
# Image 2417 done
# Image 2418 done
# Image 2419 done
# Image 2420 done
# Image 2421 done
# Image 2422 done
# Image 2423 done
# Image 2424 done
# Image 2425 done
# Image 2426 done
# Image 2427 done
# Image 2428 done
# Image 2429 done
# Image 2430 done
# Image 2431 done
# Image 2432 done
# Image 2433 done
# Image 2434 done
# Image 2435 done
# Image 2436 done
# Image 2437 done
# Image 2438 done
# Image 2439 done
# Image 2440 done
# Image 2441 done
# Image 2442 done
# Image 2443 done
# Image 2444 done
# Image 2445 done
# Image 2446 done
# Image 2447 done
# Image 2448 done
# Image 2449 done
# Image 2450 done
# Image 2451 done
# Image 2452 done
# Image 2453 done
# Image 2454 done
# Image 2455 done
# Image 2456 done
# Image 2457 done
# Image 2458 done
# Image 2459 done
# Image 2460 done
# Image 2461 done
# Image 2462 done
# Image 2463 done
# Image 2464 done
# Image 2465 done
# Image 2466 done
# Image 2467 done
# Image 2468 done
# Image 2469 done
# Image 2470 done
# Image 2471 done
# Image 2472 done
# Image 2473 done
# Image 2474 done
# Image 2475 done
# Image 2476 done
# Image 2477 done
# Image 2478 done
# Image 2479 done
# Image 2480 done
# Image 2481 done
# Image 2482 done
# Image 2483 done
# Image 2484 done
# Image 2485 done
# Image 2486 done
# Image 2487 done
# Image 2488 done
# Image 2489 done
# Image 2490 done
# Image 2491 done
# Image 2492 done
# Image 2493 done
# Image 2494 done
# Image 2495 done
# Image 2496 done
# Image 2497 done
# Image 2498 done
# Image 2499 done
# Image 2500 done
# Image 2501 done
# Image 2502 done
# Image 2503 done
# Image 2504 done
# Image 2505 done
# Image 2506 done
# Image 2507 done
# Image 2508 done
# Image 2509 done
# Image 2510 done
# Image 2511 done
# Image 2512 done
# Image 2513 done
# Image 2514 done
# Image 2515 done
# Image 2516 done
# Image 2517 done
# Image 2518 done
# Image 2519 done
# Image 2520 done
# Image 2521 done
# Image 2522 done
# Image 2523 done
# Image 2524 done
# Image 2525 done
# Image 2526 done
# Image 2527 done
# Image 2528 done
# Image 2529 done
# Image 2530 done
# Image 2531 done
# Image 2532 done
# Image 2533 done
# Image 2534 done
# Image 2535 done
# Image 2536 done
# Image 2537 done
# Image 2538 done
# Image 2539 done
# Image 2540 done
# Image 2541 done
# Image 2542 done
# Image 2543 done
# Image 2544 done
# Image 2545 done
# Image 2546 done
# Image 2547 done
# Image 2548 done
# Image 2549 done
# Image 2550 done
# Image 2551 done
# Image 2552 done
# Image 2553 done
# Image 2554 done
# Image 2555 done
# Image 2556 done
# Image 2557 done
# Image 2558 done
# Image 2559 done
# Image 2560 done
# Image 2561 done
# Image 2562 done
# Image 2563 done
# Image 2564 done
# Image 2565 done
# Image 2566 done
# Image 2567 done
# Image 2568 done
# Image 2569 done
# Image 2570 done
# Image 2571 done
# Image 2572 done
# Image 2573 done
# Image 2574 done
# Image 2575 done
# Image 2576 done
# Image 2577 done
# Image 2578 done
# Image 2579 done
# Image 2580 done
# Image 2581 done
# Image 2582 done
# Image 2583 done
# Image 2584 done
# Image 2585 done
# Image 2586 done
# Image 2587 done
# Image 2588 done
# Image 2589 done
# Image 2590 done
# Image 2591 done
# Image 2592 done
# Image 2593 done
# Image 2594 done
# Image 2595 done
# Image 2596 done
# Image 2597 done
# Image 2598 done
# Image 2599 done
# Image 2600 done
# Image 2601 done
# Image 2602 done
# Image 2603 done
# Image 2604 done
# Image 2605 done
# Image 2606 done
# Image 2607 done
# Image 2608 done
# Image 2609 done
# Image 2610 done
# Image 2611 done
# Image 2612 done
# Image 2613 done
# Image 2614 done
# Image 2615 done
# Image 2616 done
# Image 2617 done
# Image 2618 done
# Image 2619 done
# Image 2620 done
# Image 2621 done
# Image 2622 done
# Image 2623 done
# Image 2624 done
# Image 2625 done
# Image 2626 done
# Image 2627 done
# Image 2628 done
# Image 2629 done
# Image 2630 done
# Image 2631 done
# Image 2632 done
# Image 2633 done
# Image 2634 done
# Image 2635 done
# Image 2636 done
# Image 2637 done
# Image 2638 done
# Image 2639 done
# Image 2640 done
# Image 2641 done
# Image 2642 done
# Image 2643 done
# Image 2644 done
# Image 2645 done
# Image 2646 done
# Image 2647 done
# Image 2648 done
# Image 2649 done
# Image 2650 done
# Image 2651 done
# Image 2652 done
# Image 2653 done
# Image 2654 done
# Image 2655 done
# Image 2656 done
# Image 2657 done
# Image 2658 done
# Image 2659 done
# Image 2660 done
# Image 2661 done
# Image 2662 done
# Image 2663 done
# Image 2664 done
# Image 2665 done
# Image 2666 done
# Image 2667 done
# Image 2668 done
# Image 2669 done
# Image 2670 done
# Image 2671 done
# Image 2672 done
# Image 2673 done
# Image 2674 done
# Image 2675 done
# Image 2676 done
# Image 2677 done
# Image 2678 done
# Image 2679 done
# Image 2680 done
# Image 2681 done
# Image 2682 done
# Image 2683 done
# Image 2684 done
# Image 2685 done
# Image 2686 done
# Image 2687 done
# Image 2688 done
# Image 2689 done
# Image 2690 done
# Image 2691 done
# Image 2692 done
# Image 2693 done
# Image 2694 done
# Image 2695 done
# Image 2696 done
# Image 2697 done
# Image 2698 done
# Image 2699 done
# Image 2700 done
# Image 2701 done
# Image 2702 done
# Image 2703 done
# Image 2704 done
# Image 2705 done
# Image 2706 done
# Image 2707 done
# Image 2708 done
# Image 2709 done
# Image 2710 done
# Image 2711 done
# Image 2712 done
# Image 2713 done
# Image 2714 done
# Image 2715 done
# Image 2716 done
# Image 2717 done
# Image 2718 done
# Image 2719 done
# Image 2720 done
# Image 2721 done
# Image 2722 done
# Image 2723 done
# Image 2724 done
# Image 2725 done
# Image 2726 done
# Image 2727 done
# Image 2728 done
# Image 2729 done
# Image 2730 done
# Image 2731 done
# Image 2732 done
# Image 2733 done
# Image 2734 done
# Image 2735 done
# Image 2736 done
# Image 2737 done
# Image 2738 done
# Image 2739 done
# Image 2740 done
# Image 2741 done
# Image 2742 done
# Image 2743 done
# Image 2744 done
# Image 2745 done
# Image 2746 done
# Image 2747 done
# Image 2748 done
# Image 2749 done
# Image 2750 done
# Image 2751 done
# Image 2752 done
# Image 2753 done
# Image 2754 done
# Image 2755 done
# Image 2756 done
# Image 2757 done
# Image 2758 done
# Image 2759 done
# Image 2760 done
# Image 2761 done
# Image 2762 done
# Image 2763 done
# Image 2764 done
# Image 2765 done
# Image 2766 done
# Image 2767 done
# Image 2768 done
# Image 2769 done
# Image 2770 done
# Image 2771 done
# Image 2772 done
# Image 2773 done
# Image 2774 done
# Image 2775 done
# Image 2776 done
# Image 2777 done
# Image 2778 done
# Image 2779 done
# Image 2780 done
# Image 2781 done
# Image 2782 done
# Image 2783 done
# Image 2784 done
# Image 2785 done
# Image 2786 done
# Image 2787 done
# Image 2788 done
# Image 2789 done
# Image 2790 done
# Image 2791 done
# Image 2792 done
# Image 2793 done
# Image 2794 done
# Image 2795 done
# Image 2796 done
# Image 2797 done
# Image 2798 done
# Image 2799 done
# Image 2800 done
# Image 2801 done
# Image 2802 done
# Image 2803 done
# Image 2804 done
# Image 2805 done
# Image 2806 done
# Image 2807 done
# Image 2808 done
# Image 2809 done
# Image 2810 done
# Image 2811 done
# Image 2812 done
# Image 2813 done
# Image 2814 done
# Image 2815 done
# Image 2816 done
# Image 2817 done
# Image 2818 done
# Image 2819 done
# Image 2820 done
# Image 2821 done
# Image 2822 done
# Image 2823 done
# Image 2824 done
# Image 2825 done
# Image 2826 done
# Image 2827 done
# Image 2828 done
# Image 2829 done
# Image 2830 done
# Image 2831 done
# Image 2832 done
# Image 2833 done
# Image 2834 done
# Image 2835 done
# Image 2836 done
# Image 2837 done
# Image 2838 done
# Image 2839 done
# Image 2840 done
# Image 2841 done
# Image 2842 done
# Image 2843 done
# Image 2844 done
# Image 2845 done
# Image 2846 done
# Image 2847 done
# Image 2848 done
# Image 2849 done
# Image 2850 done
# Image 2851 done
# Image 2852 done
# Image 2853 done
# Image 2854 done
# Image 2855 done
# Image 2856 done
# Image 2857 done
# Image 2858 done
# Image 2859 done
# Image 2860 done
# Image 2861 done
# Image 2862 done
# Image 2863 done
# Image 2864 done
# Image 2865 done
# Image 2866 done
# Image 2867 done
# Image 2868 done
# Image 2869 done
# Image 2870 done
# Image 2871 done
# Image 2872 done
# Image 2873 done
# Image 2874 done
# Image 2875 done
# Image 2876 done
# Image 2877 done
# Image 2878 done
# Image 2879 done
# Image 2880 done
# Image 2881 done
# Image 2882 done
# Image 2883 done
# Image 2884 done
# Image 2885 done
# Image 2886 done
# Image 2887 done
# Image 2888 done
# Image 2889 done
# Image 2890 done
# Image 2891 done
# Image 2892 done
# Image 2893 done
# Image 2894 done
# Image 2895 done
# Image 2896 done
# Image 2897 done
# Image 2898 done
# Image 2899 done
# Image 2900 done
# Image 2901 done
# Image 2902 done
# Image 2903 done
# Image 2904 done
# Image 2905 done
# Image 2906 done
# Image 2907 done
# Image 2908 done
# Image 2909 done
# Image 2910 done
# Image 2911 done
# Image 2912 done
# Image 2913 done
# Image 2914 done
# Image 2915 done
# Image 2916 done
# Image 2917 done
# Image 2918 done
# Image 2919 done
# Image 2920 done
# Image 2921 done
# Image 2922 done
# Image 2923 done
# Image 2924 done
# Image 2925 done
# Image 2926 done
# Image 2927 done
# Image 2928 done
# Image 2929 done
# Image 2930 done
# Image 2931 done
# Image 2932 done
# Image 2933 done
# Image 2934 done
# Image 2935 done
# Image 2936 done
# Image 2937 done
# Image 2938 done
# Image 2939 done
# Image 2940 done
# Image 2941 done
# Image 2942 done
# Image 2943 done
# Image 2944 done
# Image 2945 done
# Image 2946 done
# Image 2947 done
# Image 2948 done
# Image 2949 done
# Image 2950 done
# Image 2951 done
# Image 2952 done
# Image 2953 done
# Image 2954 done
# Image 2955 done
# Image 2956 done
# Image 2957 done
# Image 2958 done
# Image 2959 done
# Image 2960 done
# Image 2961 done
# Image 2962 done
# Image 2963 done
# Image 2964 done
# Image 2965 done
# Image 2966 done
# Image 2967 done
# Image 2968 done
# Image 2969 done
# Image 2970 done
# Image 2971 done
# Image 2972 done
# Image 2973 done
# Image 2974 done
# Image 2975 done
# Image 2976 done
# Image 2977 done
# Image 2978 done
# Image 2979 done
# Image 2980 done
# Image 2981 done
# Image 2982 done
# Image 2983 done
# Image 2984 done
# Image 2985 done
# Image 2986 done
# Image 2987 done
# Image 2988 done
# Image 2989 done
# Image 2990 done
# Image 2991 done
# Image 2992 done
# Image 2993 done
# Image 2994 done
# Image 2995 done
# Image 2996 done
# Image 2997 done
# Image 2998 done
# Image 2999 done
# Image 3000 done
# Image 3001 done
# Image 3002 done
# Image 3003 done
# Image 3004 done
# Image 3005 done
# Image 3006 done
# Image 3007 done
# Image 3008 done
# Image 3009 done
# Image 3010 done
# Image 3011 done
# Image 3012 done
# Image 3013 done
# Image 3014 done
# Image 3015 done
# Image 3016 done
# Image 3017 done
# Image 3018 done
# Image 3019 done
# Image 3020 done
# Image 3021 done
# Image 3022 done
# Image 3023 done
# Image 3024 done
# Image 3025 done
# Image 3026 done
# Image 3027 done
# Image 3028 done
# Image 3029 done
# Image 3030 done
# Image 3031 done
# Image 3032 done
# Image 3033 done
# Image 3034 done
# Image 3035 done
# Image 3036 done
# Image 3037 done
# Image 3038 done
# Image 3039 done
# Image 3040 done
# Image 3041 done
# Image 3042 done
# Image 3043 done
# Image 3044 done
# Image 3045 done
# Image 3046 done
# Image 3047 done
# Image 3048 done
# Image 3049 done
# Image 3050 done
# Image 3051 done
# Image 3052 done
# Image 3053 done
# Image 3054 done
# Image 3055 done
# Image 3056 done
# Image 3057 done
# Image 3058 done
# Image 3059 done
# Image 3060 done
# Image 3061 done
# Image 3062 done
# Image 3063 done
# Image 3064 done
# Image 3065 done
# Image 3066 done
# ...
# Image 3344 done
# Image 3345 done
# Image 3346 done
# Image 3347 done
# Image 3348 done
# Image 3349 done
# Image 3350 done
# Image 3351 done
# Image 3352 done
# Image 3353 done
# Image 3354 done
# Image 3355 done
# Image 3356 done
# Image 3357 done
# Image 3358 done
# Image 3359 done
# Image 3360 done
# Image 3361 done
# Image 3362 done
# Image 3363 done
# Image 3364 done
# Image 3365 done
# Image 3366 done
# Image 3367 done
# Image 3368 done
# Image 3369 done
# Image 3370 done
# Image 3371 done
# Image 3372 done
# Image 3373 done
# Image 3374 done
# Image 3375 done
# Image 3376 done
# Image 3377 done
# Image 3378 done
# Image 3379 done
# Image 3380 done
# Image 3381 done
# Image 3382 done
# Image 3383 done
# Image 3384 done
# Image 3385 done
# Image 3386 done
# Image 3387 done
# Image 3388 done
# Image 3389 done
# Image 3390 done
# Image 3391 done
# Image 3392 done
# Image 3393 done
# Image 3394 done
# Image 3395 done
# Image 3396 done
# Image 3397 done
# Image 3398 done
# Image 3399 done
# Image 3400 done
# Image 3401 done
# Image 3402 done
# Image 3403 done
# Image 3404 done
# Image 3405 done
# Image 3406 done
# Image 3407 done
# Image 3408 done
# Image 3409 done
# Image 3410 done
# Image 3411 done
# Image 3412 done
# Image 3413 done
# Image 3414 done
# Image 3415 done
# Image 3416 done
# Image 3417 done
# Image 3418 done
# Image 3419 done
# Image 3420 done
# Image 3421 done
# Image 3422 done
# Image 3423 done
# Image 3424 done
# Image 3425 done
# Image 3426 done
# Image 3427 done
# Image 3428 done
# Image 3429 done
# Image 3430 done
# Image 3431 done
# Image 3432 done
# Image 3433 done
# Image 3434 done
# Image 3435 done
# Image 3436 done
# Image 3437 done
# Image 3438 done
# Image 3439 done
# Image 3440 done
# Image 3441 done
# Image 3442 done
# Image 3443 done
# Image 3444 done
# Image 3445 done
# Image 3446 done
# Image 3447 done
# Image 3448 done
# Image 3449 done
# Image 3450 done
# Image 3451 done
# Image 3452 done
# Image 3453 done
# Image 3454 done
# Image 3455 done
# Image 3456 done
# Image 3457 done
# Image 3458 done
# Image 3459 done
# Image 3460 done
# Image 3461 done
# Image 3462 done
# Image 3463 done
# Image 3464 done
# Image 3465 done
# Image 3466 done
# Image 3467 done
# Image 3468 done
# Image 3469 done
# Image 3470 done
# Image 3471 done
# Image 3472 done
# Image 3473 done
# Image 3474 done
# Image 3475 done
# Image 3476 done
# Image 3477 done
# Image 3478 done
# Image 3479 done
# Image 3480 done
# Image 3481 done
# Image 3482 done
# Image 3483 done
# Image 3484 done
# Image 3485 done
# Image 3486 done
# Image 3487 done
# Image 3488 done
# Image 3489 done
# Image 3490 done
# Image 3491 done
# Image 3492 done
# Image 3493 done
# Image 3494 done
# Image 3495 done
# Image 3496 done
# Image 3497 done
# Image 3498 done
# Image 3499 done
# Image 3500 done
# Image 3501 done
# Image 3502 done
# Image 3503 done
# Image 3504 done
# Image 3505 done
# Image 3506 done
# Image 3507 done
# Image 3508 done
# Image 3509 done
# Image 3510 done
# Image 3511 done
# Image 3512 done
# Image 3513 done
# Image 3514 done
# Image 3515 done
# Image 3516 done
# Image 3517 done
# Image 3518 done
# Image 3519 done
# Image 3520 done
# Image 3521 done
# Image 3522 done
# Image 3523 done
# Image 3524 done
# Image 3525 done
# Image 3526 done
# Image 3527 done
# Image 3528 done
# Image 3529 done
# Image 3530 done
# Image 3531 done
# Image 3532 done
# Image 3533 done
# Image 3534 done
# Image 3535 done
# Image 3536 done
# Image 3537 done
# Image 3538 done
# Image 3539 done
# Image 3540 done
# Image 3541 done
# Image 3542 done
# Image 3543 done
# Image 3544 done
# Image 3545 done
# Image 3546 done
# Image 3547 done
# Image 3548 done
# Image 3549 done
# Image 3550 done
# Image 3551 done
# Image 3552 done
# Image 3553 done
# Image 3554 done
# Image 3555 done
# Image 3556 done
# Image 3557 done
# Image 3558 done
# Image 3559 done
# Image 3560 done
# Image 3561 done
# Image 3562 done
# Image 3563 done
# Image 3564 done
# Image 3565 done
# Image 3566 done
# Image 3567 done
# Image 3568 done
# Image 3569 done
# Image 3570 done
# Image 3571 done
# Image 3572 done
# Image 3573 done
# Image 3574 done
# Image 3575 done
# Image 3576 done
# Image 3577 done
# Image 3578 done
# Image 3579 done
# Image 3580 done
# Image 3581 done
# Image 3582 done
# Image 3583 done
# Image 3584 done
# Image 3585 done
# Image 3586 done
# Image 3587 done
# Image 3588 done
# Image 3589 done
# Image 3590 done
# Image 3591 done
# Image 3592 done
# Image 3593 done
# Image 3594 done
# Image 3595 done
# Image 3596 done
# Image 3597 done
# Image 3598 done
# Image 3599 done
# Image 3600 done
# Image 3601 done
# Image 3602 done
# Image 3603 done
# Image 3604 done
# Image 3605 done
# Image 3606 done
# Image 3607 done
# Image 3608 done
# Image 3609 done
# Image 3610 done
# Image 3611 done
# Image 3612 done
# Image 3613 done
# Image 3614 done
# Image 3615 done
# Image 3616 done
# Image 3617 done
# Image 3618 done
# Image 3619 done
# Image 3620 done
# Image 3621 done
# Image 3622 done
# Image 3623 done
# Image 3624 done
# Image 3625 done
# Image 3626 done
# Image 3627 done
# Image 3628 done
# Image 3629 done
# Image 3630 done
# Image 3631 done
# Image 3632 done
# Image 3633 done
# Image 3634 done
# Image 3635 done
# Image 3636 done
# Image 3637 done
# Image 3638 done
# Image 3639 done
# Image 3640 done
# Image 3641 done
# Image 3642 done
# Image 3643 done
# Image 3644 done
# Image 3645 done
# Image 3646 done
# Image 3647 done
# Image 3648 done
# Image 3649 done
# Image 3650 done
# Image 3651 done
# Image 3652 done
# Image 3653 done
# Image 3654 done
# Image 3655 done
# Image 3656 done
# Image 3657 done
# Image 3658 done
# Image 3659 done
# Image 3660 done
# Image 3661 done
# Image 3662 done
# Image 3663 done
# Image 3664 done
# Image 3665 done
# Image 3666 done
# Image 3667 done
# Image 3668 done
# Image 3669 done
# Image 3670 done
# Image 3671 done
# Image 3672 done
# Image 3673 done
# Image 3674 done
# Image 3675 done
# Image 3676 done
# Image 3677 done
# Image 3678 done
# Image 3679 done
# Image 3680 done
# Image 3681 done
# Image 3682 done
# Image 3683 done
# Image 3684 done
# Image 3685 done
# Image 3686 done
# Image 3687 done
# Image 3688 done
# Image 3689 done
# Image 3690 done
# Image 3691 done
# Image 3692 done
# Image 3693 done
# Image 3694 done
# Image 3695 done
# Image 3696 done
# Image 3697 done
# Image 3698 done
# Image 3699 done
# Image 3700 done
# Image 3701 done
# Image 3702 done
# Image 3703 done
# Image 3704 done
# Image 3705 done
# Image 3706 done
# Image 3707 done
# Image 3708 done
# Image 3709 done
# Image 3710 done
# Image 3711 done
# Image 3712 done
# Image 3713 done
# Image 3714 done
# Image 3715 done
# Image 3716 done
# Image 3717 done
# Image 3718 done
# Image 3719 done
# Image 3720 done
# Image 3721 done
# Image 3722 done
# Image 3723 done
# Image 3724 done
# Image 3725 done
# Image 3726 done
# Image 3727 done
# Image 3728 done
# Image 3729 done
# Image 3730 done
# Image 3731 done
# Image 3732 done
# Image 3733 done
# Image 3734 done
# Image 3735 done
# Image 3736 done
# Image 3737 done
# Image 3738 done
# Image 3739 done
# Image 3740 done
# Image 3741 done
# Image 3742 done
# Image 3743 done
# Image 3744 done
# Image 3745 done
# Image 3746 done
# Image 3747 done
# Image 3748 done
# Image 3749 done
# Image 3750 done
# Image 3751 done
# Image 3752 done
# Image 3753 done
# Image 3754 done
# Image 3755 done
# Image 3756 done
# Image 3757 done
# Image 3758 done
# Image 3759 done
# Image 3760 done
# Image 3761 done
# Image 3762 done
# Image 3763 done
# Image 3764 done
# Image 3765 done
# Image 3766 done
# Image 3767 done
# Image 3768 done
# Image 3769 done
# Image 3770 done
# Image 3771 done
# Image 3772 done
# Image 3773 done
# Image 3774 done
# Image 3775 done
# Image 3776 done
# Image 3777 done
# Image 3778 done
# Image 3779 done
# Image 3780 done
# Image 3781 done
# Image 3782 done
# Image 3783 done
# Image 3784 done
# Image 3785 done
# Image 3786 done
# Image 3787 done
# Image 3788 done
# Image 3789 done
# Image 3790 done
# Image 3791 done
# Image 3792 done
# Image 3793 done
# Image 3794 done
# Image 3795 done
# Image 3796 done
# Image 3797 done
# Image 3798 done
# Image 3799 done
# Image 3800 done
# Image 3801 done
# Image 3802 done
# Image 3803 done
# Image 3804 done
# Image 3805 done
# Image 3806 done
# Image 3807 done
# Image 3808 done
# Image 3809 done
# Image 3810 done
# Image 3811 done
# Image 3812 done
# Image 3813 done
# Image 3814 done
# Image 3815 done
# Image 3816 done
# Image 3817 done
# Image 3818 done
# Image 3819 done
# Image 3820 done
# Image 3821 done
# Image 3822 done
# Image 3823 done
# Image 3824 done
# Image 3825 done
# Image 3826 done
# Image 3827 done
# Image 3828 done
# Image 3829 done
# Image 3830 done
# Image 3831 done
# Image 3832 done
# Image 3833 done
# Image 3834 done
# Image 3835 done
# Image 3836 done
# Image 3837 done
# Image 3838 done
# Image 3839 done
# Image 3840 done
# Image 3841 done
# Image 3842 done
# Image 3843 done
# Image 3844 done
# Image 3845 done
# Image 3846 done
# Image 3847 done
# Image 3848 done
# Image 3849 done
# Image 3850 done
# Image 3851 done
# Image 3852 done
# Image 3853 done
# Image 3854 done
# Image 3855 done
# Image 3856 done
# Image 3857 done
# Image 3858 done
# Image 3859 done
# Image 3860 done
# Image 3861 done
# Image 3862 done
# Image 3863 done
# Image 3864 done
# Image 3865 done
# Image 3866 done
# Image 3867 done
# Image 3868 done
# Image 3869 done
# Image 3870 done
# Image 3871 done
# Image 3872 done
# Image 3873 done
# Image 3874 done
# Image 3875 done
# Image 3876 done
# Image 3877 done
# Image 3878 done
# Image 3879 done
# Image 3880 done
# Image 3881 done
# Image 3882 done
# Image 3883 done
# Image 3884 done
# Image 3885 done
# Image 3886 done
# Image 3887 done
# Image 3888 done
# Image 3889 done
# Image 3890 done
# Image 3891 done
# Image 3892 done
# Image 3893 done
# Image 3894 done
# Image 3895 done
# Image 3896 done
# Image 3897 done
# Image 3898 done
# Image 3899 done
# Image 3900 done
# Image 3901 done
# Image 3902 done
# Image 3903 done
# Image 3904 done
# Image 3905 done
# Image 3906 done
# Image 3907 done
# Image 3908 done
# Image 3909 done
# Image 3910 done
# Image 3911 done
# Image 3912 done
# Image 3913 done
# Image 3914 done
# Image 3915 done
# Image 3916 done
# Image 3917 done
# Image 3918 done
# Image 3919 done
# Image 3920 done
# Image 3921 done
# Image 3922 done
# Image 3923 done
# Image 3924 done
# Image 3925 done
# Image 3926 done
# Image 3927 done
# Image 3928 done
# Image 3929 done
# Image 3930 done
# Image 3931 done
# Image 3932 done
# Image 3933 done
# Image 3934 done
# Image 3935 done
# Image 3936 done
# Image 3937 done
# Image 3938 done
# Image 3939 done
# Image 3940 done
# Image 3941 done
# Image 3942 done
# Image 3943 done
# Image 3944 done
# Image 3945 done
# Image 3946 done
# Image 3947 done
# Image 3948 done
# Image 3949 done
# Image 3950 done
# Image 3951 done
# Image 3952 done
# Image 3953 done
# Image 3954 done
# Image 3955 done
# Image 3956 done
# Image 3957 done
# Image 3958 done
# Image 3959 done
# Image 3960 done
# Image 3961 done
# Image 3962 done
# Image 3963 done
# Image 3964 done
# Image 3965 done
# Image 3966 done
# Image 3967 done
# Image 3968 done
# Image 3969 done
# Image 3970 done
# Image 3971 done
# Image 3972 done
# Image 3973 done
# Image 3974 done
# Image 3975 done
# Image 3976 done
# Image 3977 done
# Image 3978 done
# Image 3979 done
# Image 3980 done
# Image 3981 done
# Image 3982 done
# Image 3983 done
# Image 3984 done
# Image 3985 done
# Image 3986 done
# Image 3987 done
# Image 3988 done
# Image 3989 done
# Image 3990 done
# Image 3991 done
# Image 3992 done
# Image 3993 done
# Image 3994 done
# Image 3995 done
# Image 3996 done
# Image 3997 done
# Image 3998 done
# Image 3999 done
# Image 4000 done
# Image 4001 done
# Image 4002 done
# Image 4003 done
# Image 4004 done
# Image 4005 done
# Image 4006 done
# Image 4007 done
# Image 4008 done
# Image 4009 done
# Image 4010 done
# Image 4011 done
# Image 4012 done
# Image 4013 done
# Image 4014 done
# Image 4015 done
# Image 4016 done
# Image 4017 done
# Image 4018 done
# Image 4019 done
# Image 4020 done
# Image 4021 done
# Image 4022 done
# Image 4023 done
# Image 4024 done
# Image 4025 done
# Image 4026 done
# Image 4027 done
# Image 4028 done
# Image 4029 done
# Image 4030 done
# Image 4031 done
# Image 4032 done
# Image 4033 done
# Image 4034 done
# Image 4035 done
# Image 4036 done
# Image 4037 done
# Image 4038 done
# Image 4039 done
# Image 4040 done
# Image 4041 done
# Image 4042 done
# Image 4043 done
# Image 4044 done
# Image 4045 done
# Image 4046 done
# Image 4047 done
# Image 4048 done
# Image 4049 done
# Image 4050 done
# Image 4051 done
# Image 4052 done
# Image 4053 done
# Image 4054 done
# Image 4055 done
# Image 4056 done
# Image 4057 done
# Image 4058 done
# Image 4059 done
# Image 4060 done
# Image 4061 done
# Image 4062 done
# Image 4063 done
# Image 4064 done
# Image 4065 done
# Image 4066 done
# Image 4067 done
# Image 4068 done
# Image 4069 done
# Image 4070 done
# Image 4071 done
# Image 4072 done
# Image 4073 done
# Image 4074 done
# Image 4075 done
# Image 4076 done
# Image 4077 done
# Image 4078 done
# Image 4079 done
# Image 4080 done
# Image 4081 done
# Image 4082 done
# Image 4083 done
# Image 4084 done
# Image 4085 done
# Image 4086 done
# Image 4087 done
# Image 4088 done
# Image 4089 done
# Image 4090 done
# Image 4091 done
# Image 4092 done
# Image 4093 done
# Image 4094 done
# Image 4095 done
# Image 4096 done
# Image 4097 done
# Image 4098 done
# Image 4099 done
# Image 4100 done
# Image 4101 done
# Image 4102 done
# Image 4103 done
# Image 4104 done
# Image 4105 done
# Image 4106 done
# Image 4107 done
# Image 4108 done
# Image 4109 done
# Image 4110 done
# Image 4111 done
# Image 4112 done
# Image 4113 done
# Image 4114 done
# Image 4115 done
# Image 4116 done
# Image 4117 done
# Image 4118 done
# Image 4119 done
# Image 4120 done
# Image 4121 done
# Image 4122 done
# Image 4123 done
# Image 4124 done
# Image 4125 done
# Image 4126 done
# Image 4127 done
# Image 4128 done
# Image 4129 done
# Image 4130 done
# Image 4131 done
# Image 4132 done
# Image 4133 done
# Image 4134 done
# Image 4135 done
# Image 4136 done
# Image 4137 done
# Image 4138 done
# Image 4139 done
# Image 4140 done
# Image 4141 done
# Image 4142 done
# Image 4143 done
# Image 4144 done
# Image 4145 done
# Image 4146 done
# Image 4147 done
# Image 4148 done
# Image 4149 done
# Image 4150 done
# Image 4151 done
# Image 4152 done
# Image 4153 done
# Image 4154 done
# Image 4155 done
# Image 4156 done
# Image 4157 done
# Image 4158 done
# Image 4159 done
# Image 4160 done
# Image 4161 done
# Image 4162 done
# Image 4163 done
# Image 4164 done
# Image 4165 done
# Image 4166 done
# Image 4167 done
# Image 4168 done
# Image 4169 done
# Image 4170 done
# Image 4171 done
# Image 4172 done
# Image 4173 done
# Image 4174 done
# Image 4175 done
# Image 4176 done
# Image 4177 done
# Image 4178 done
# Image 4179 done
# Image 4180 done
# Image 4181 done
# Image 4182 done
# Image 4183 done
# Image 4184 done
# Image 4185 done
# Image 4186 done
# Image 4187 done
# Image 4188 done
# Image 4189 done
# Image 4190 done
# Image 4191 done
# Image 4192 done
# Image 4193 done
# Image 4194 done
# Image 4195 done
# Image 4196 done
# Image 4197 done
# Image 4198 done
# Image 4199 done
# Image 4200 done
# Image 4201 done
# Image 4202 done
# Image 4203 done
# Image 4204 done
# Image 4205 done
# Image 4206 done
# Image 4207 done
# Image 4208 done
# Image 4209 done
# Image 4210 done
# Image 4211 done
# Image 4212 done
# Image 4213 done
# Image 4214 done
# Image 4215 done
# Image 4216 done
# Image 4217 done
# Image 4218 done
# Image 4219 done
# Image 4220 done
# Image 4221 done
# Image 4222 done
# Image 4223 done
# Image 4224 done
# Image 4225 done
# Image 4226 done
# Image 4227 done
# Image 4228 done
# Image 4229 done
# Image 4230 done
# Image 4231 done
# Image 4232 done
# Image 4233 done
# Image 4234 done
# Image 4235 done
# Image 4236 done
# Image 4237 done
# Image 4238 done
# Image 4239 done
# Image 4240 done
# Image 4241 done
# Image 4242 done
# Image 4243 done
# Image 4244 done
# Image 4245 done
# Image 4246 done
# Image 4247 done
# Image 4248 done
# Image 4249 done
# Image 4250 done
# Image 4251 done
# Image 4252 done
# Image 4253 done
# Image 4254 done
# Image 4255 done
# Image 4256 done
# Image 4257 done
# Image 4258 done
# Image 4259 done
# Image 4260 done
# Image 4261 done
# Image 4262 done
# Image 4263 done
# Image 4264 done
# Image 4265 done
# Image 4266 done
# Image 4267 done
# Image 4268 done
# Image 4269 done
# Image 4270 done
# Image 4271 done
# Image 4272 done
# Image 4273 done
# Image 4274 done
# Image 4275 done
# Image 4276 done
# Image 4277 done
# Image 4278 done
# Image 4279 done
# Image 4280 done
# Image 4281 done
# Image 4282 done
# Image 4283 done
# Image 4284 done
# Image 4285 done
# Image 4286 done
# Image 4287 done
# Image 4288 done
# Image 4289 done
# Image 4290 done
# Image 4291 done
# Image 4292 done
# Image 4293 done
# Image 4294 done
# Image 4295 done
# Image 4296 done
# Image 4297 done
# Image 4298 done
# Image 4299 done
# Image 4300 done
# Image 4301 done
# Image 4302 done
# Image 4303 done
# Image 4304 done
# Image 4305 done
# Image 4306 done
# Image 4307 done
# Image 4308 done
# Image 4309 done
# Image 4310 done
# Image 4311 done
# Image 4312 done
# Image 4313 done
# Image 4314 done
# Image 4315 done
# Image 4316 done
# Image 4317 done
# Image 4318 done
# Image 4319 done
# Image 4320 done
# Image 4321 done
# Image 4322 done
# Image 4323 done
# Image 4324 done
# Image 4325 done
# Image 4326 done
# Image 4327 done
# Image 4328 done
# Image 4329 done
# Image 4330 done
# Image 4331 done
# Image 4332 done
# Image 4333 done
# Image 4334 done
# Image 4335 done
# Image 4336 done
# Image 4337 done
# Image 4338 done
# Image 4339 done
# Image 4340 done
# Image 4341 done
# [INFO] Process done

# %%
# get the overall feature vector size
print("[STATUS] feature vector size {}".format(np.array(data).shape))

# get the overall training label size
print("[STATUS] training Labels {}".format(np.array(labels).shape))

# encode the target labels
targetNames = np.unique(labels)
le          = LabelEncoder()
target      = le.fit_transform(labels)
print("[STATUS] training labels encoded...")

# scale features in the range (0-1)
scaler            = MinMaxScaler(feature_range=(0, 1))
rescaled_features = scaler.fit_transform(data)
print("[STATUS] feature vector normalized...")

print("[STATUS] target labels: {}".format(target))
print("[STATUS] target labels shape: {}".format(target.shape))

print("[STATUS] end of training..")
# Out:
# [STATUS] feature vector size (4341, 532)
# [STATUS] training Labels (4341,)
# [STATUS] training labels encoded...
# [STATUS] feature vector normalized...
# [STATUS] target labels: [0 0 0 ... 1 1 1]
# [STATUS] target labels shape: (4341,)
# [STATUS] end of training..

# %%
# perform a training and testing split, using 75% of the data for
# training and 25% for evaluation
(trainX, testX, trainY, testY) = train_test_split(rescaled_features, target,
    test_size=0.25, random_state=9)

# %%
k_range = range(1, 14)
scores = []
scores1 = []
error_rates = []

for k in k_range:
    # train the model
    print("[INFO] nilai k = {}".format(k))
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(trainX, trainY)
 
    # make predictions on our data and show a classification report
    print("[INFO] evaluating...")
    predictions = model.predict(testX)
    predictions1 = model.predict(trainX)
    scores.append(metrics.accuracy_score(testY, predictions))
    scores1.append(metrics.accuracy_score(trainY, predictions1))
    error_rates.append(np.mean(predictions != testY))
    print(confusion_matrix(testY, predictions))
    print(classification_report(testY, predictions, target_names=le.classes_))
# Out:
# [INFO] nilai k = 1
# [INFO] evaluating...
# [[316 163]
#  [187 420]]
#               precision    recall  f1-score   support
#
#      Beracun       0.63      0.66      0.64       479
# TidakBeracun       0.72      0.69      0.71       607
#
#    micro avg       0.68      0.68      0.68      1086
#    macro avg       0.67      0.68      0.67      1086
# weighted avg       0.68      0.68      0.68      1086
#
# [INFO] nilai k = 2
# [INFO] evaluating...
# [[408  71]
#  [334 273]]
#               precision    recall  f1-score   support
#
#      Beracun       0.55      0.85      0.67       479
# TidakBeracun       0.79      0.45      0.57       607
#
#    micro avg       0.63      0.63      0.63      1086
#    macro avg       0.67      0.65      0.62      1086
# weighted avg       0.69      0.63      0.62      1086
#
# [INFO] nilai k = 3
# [INFO] evaluating...
# [[286 193]
#  [205 402]]
#               precision    recall  f1-score   support
#
#      Beracun       0.58      0.60      0.59       479
# TidakBeracun       0.68      0.66      0.67       607
#
#    micro avg       0.63      0.63      0.63      1086
#    macro avg       0.63      0.63      0.63      1086
# weighted avg       0.63      0.63      0.63      1086
#
# [INFO] nilai k = 4
# [INFO] evaluating...
# [[351 128]
#  [292 315]]
#               precision    recall  f1-score   support
#
#      Beracun       0.55      0.73      0.63       479
# TidakBeracun       0.71      0.52      0.60       607
#
#    micro avg       0.61      0.61      0.61      1086
#    macro avg       0.63      0.63      0.61      1086
# weighted avg       0.64      0.61      0.61      1086
#
# [INFO] nilai k = 5
# [INFO] evaluating...
# [[272 207]
#  [189 418]]
#               precision    recall  f1-score   support
#
#      Beracun       0.59      0.57      0.58       479
# TidakBeracun       0.67      0.69      0.68       607
#
#    micro avg       0.64      0.64      0.64      1086
#    macro avg       0.63      0.63      0.63      1086
# weighted avg       0.63      0.64      0.63      1086
#
# [INFO] nilai k = 6
# [INFO] evaluating...
# [[332 147]
#  [260 347]]
#               precision    recall  f1-score   support
#
#      Beracun       0.56      0.69      0.62       479
# TidakBeracun       0.70      0.57      0.63       607
#
#    micro avg       0.63      0.63      0.63      1086
#    macro avg       0.63      0.63      0.63      1086
# weighted avg       0.64      0.63      0.63      1086
#
# [INFO] nilai k = 7
# [INFO] evaluating...
# [[277 202]
#  [188 419]]
#               precision    recall  f1-score   support
#
#      Beracun       0.60      0.58      0.59       479
# TidakBeracun       0.67      0.69      0.68       607
#
#    micro avg       0.64      0.64      0.64      1086
#    macro avg       0.64      0.63      0.63      1086
# weighted avg       0.64      0.64      0.64      1086
#
# [INFO] nilai k = 8
# [INFO] evaluating...
# [[322 157]
#  [243 364]]
#               precision    recall  f1-score   support
#
#      Beracun       0.57      0.67      0.62       479
# TidakBeracun       0.70      0.60      0.65       607
#
#    micro avg       0.63      0.63      0.63      1086
#    macro avg       0.63      0.64      0.63      1086
# weighted avg       0.64      0.63      0.63      1086
#
# [INFO] nilai k = 9
# [INFO] evaluating...
# [[273 206]
#  [191 416]]
#               precision    recall  f1-score   support
#
#      Beracun       0.59      0.57      0.58       479
# TidakBeracun       0.67      0.69      0.68       607
#
#    micro avg       0.63      0.63      0.63      1086
#    macro avg       0.63      0.63      0.63      1086
# weighted avg       0.63      0.63      0.63      1086
#
# [INFO] nilai k = 10
# [INFO] evaluating...
# [[321 158]
#  [244 363]]
#               precision    recall  f1-score   support
#
#      Beracun       0.57      0.67      0.61       479
# TidakBeracun       0.70      0.60      0.64       607
#
#    micro avg       0.63      0.63      0.63      1086
#    macro avg       0.63      0.63      0.63      1086
# weighted avg       0.64      0.63      0.63      1086
#
# [INFO] nilai k = 11
# [INFO] evaluating...
# [[268 211]
#  [193 414]]
#               precision    recall  f1-score   support
#
#      Beracun       0.58      0.56      0.57       479
# TidakBeracun       0.66      0.68      0.67       607
#
#    micro avg       0.63      0.63      0.63      1086
#    macro avg       0.62      0.62      0.62      1086
# weighted avg       0.63      0.63      0.63      1086
#
# [INFO] nilai k = 12
# [INFO] evaluating...
# [[302 177]
#  [233 374]]
#               precision    recall  f1-score   support
#
#      Beracun       0.56      0.63      0.60       479
# TidakBeracun       0.68      0.62      0.65       607
#
#    micro avg       0.62      0.62      0.62      1086
#    macro avg       0.62      0.62      0.62      1086
# weighted avg       0.63      0.62      0.62      1086
#
# [INFO] nilai k = 13
# [INFO] evaluating...
# [[252 227]
#  [187 420]]
#               precision    recall  f1-score   support
#
#      Beracun       0.57      0.53      0.55       479
# TidakBeracun       0.65      0.69      0.67       607
#
#    micro avg       0.62      0.62      0.62      1086
#    macro avg       0.61      0.61      0.61      1086
# weighted avg       0.62      0.62      0.62      1086

# %%
# allow plots to appear within the notebook
# %matplotlib inline

# plot the relationship between K and testing accuracy
# plt.plot(x_axis, y_axis)
plt.plot(k_range, scores, color="r", label="Akurasi Test")
\\plt.plot(k_range, scores1, "--b", label="Akurasi Training")
plt.xlim(0, 14)
plt.xlabel('Nilai k neighbor')
plt.ylabel('Akurasi')
leg = plt.legend();
fig = plt.gcf()
# Out:
#   File "<ipython-input-2-9a08effe797e>", line 7
#     \\plt.plot(k_range, scores1, "--b", label="Akurasi Training")
#                                                                  ^
# SyntaxError: unexpected character after line continuation character
